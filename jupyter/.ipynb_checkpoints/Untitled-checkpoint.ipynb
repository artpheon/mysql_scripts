# %%
import pandas as pd

# %%
excel = pd.read_excel('/Users/hrobbin/projects/python/Bosch/ticket_search_2021-09-02_08-13.xlsx', sheet_name=0)

# %%
import re

# %%
excel
# Out:
#     Номер заявки      Возраст             Создан/а             Закрытые  \
# 0       10101259   1 ч 52 мин  2021-09-02 06:20:24  2021-09-02 06:37:04
# 1       10101258   2 ч 52 мин  2021-09-02 05:20:23  2021-09-02 06:15:03
# 2       10101246  15 ч 22 мин  2021-09-01 16:50:22  2021-09-01 16:58:20
# 3       10101243  15 ч 52 мин  2021-09-01 16:20:19  2021-09-01 16:32:15
# 4       10101224  17 ч 32 мин  2021-09-01 14:40:21  2021-09-01 15:00:48
# 5       10101223  17 ч 32 мин  2021-09-01 14:40:21  2021-09-01 14:59:29
# 6       10101216  18 ч 12 мин  2021-09-01 14:00:17  2021-09-01 14:16:34
# 7       10101213  18 ч 32 мин  2021-09-01 13:40:17  2021-09-01 13:51:28
# 8       10101176  22 ч 32 мин  2021-09-01 09:40:13  2021-09-01 09:53:50
# 9       10101175  22 ч 32 мин  2021-09-01 09:40:13  2021-09-01 09:48:20
# 10      10101173  22 ч 52 мин  2021-09-01 09:20:11  2021-09-01 09:32:52
# 11      10101171  23 ч 12 мин  2021-09-01 09:00:11  2021-09-01 09:03:22
#
# ...

# %%
sample = excel.iloc[2, 1]
sample = '1 day 2 h 33 minutes'
res = re.search(r"(\d+)\D+(\d+)\D+(\d+)", sample)
if not res:
    res = re.search(r"(\d+)\D+(\d+)", sample)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/zz/zyxvpxvq6csfxvn_n003vfyc00yvql/T/ipykernel_11737/2217774300.py in <module>
#       4 if not res:
#       5     res = re.search(r"(\d+)\D+(\d+)", sample)
# ----> 6 res.size()
#
# AttributeError: 're.Match' object has no attribute 'size'

# %%
res.group(3)
# Out:
# '33'
