# %%
import pandas as pd
import re

# %%
file = pd.read_excel('/Users/hrobbin/projects/python/Bosch/JivoChat Report 21-09-02 61305d4165b6d.xlsx', sheet_name=0)

# %%
def format_date(raw):
    date = re.search(r"\D(\d{1,}).(\d{1,}).(\d{1,})", raw)
    return date.group(3) + '-' + date.group(2) + '-' + date.group(1)

# %%
file.columns = ['x' + str(x) for x in range(13)]
start = file.loc[file['x0'] == 'Сводный отчет по сайтам'].index[0]
ends = file.loc[file['x0'] == 'ИТОГО'].index[0]
file2 = pd.DataFrame(file.iloc[start + 3:ends, :7])
file2.columns = ['site_name', 'dial_acc', 'call_acc', 'dial_not_acc', 'call_not_acc', 'dial_noreply', 'offline_msg']
file2.reset_index(inplace=True)
file2['date'] = format_date(file.iloc[0, 0])
file2.insert(0, 'date', file2.pop('date'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/zz/zyxvpxvq6csfxvn_n003vfyc00yvql/T/ipykernel_76834/1506944620.py in <module>
#       4 file2 = pd.DataFrame(file.iloc[start + 3:ends, :7])
#       5 file2.reset_index(inplace=True)
# ----> 6 file2.columns = ['site_name', 'dial_acc', 'call_acc', 'dial_non_acc', 'call_non_acc', 'dial_no_reply', 'offline_msg']
#       7 file2['date'] = format_date(file.iloc[0, 0])
#       8 file2.insert(0, 'date', file2.pop('date'))
#
# ~/projects/python/Bosch/venv/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# ~/projects/python/Bosch/venv/lib/python3.7/site-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/projects/python/Bosch/venv/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     764     def _set_axis(self, axis: int, labels: Index) -> None:
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#     767         self._clear_item_cache()
#     768
#
# ~/projects/python/Bosch/venv/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     214     def set_axis(self, axis: int, new_labels: Index) -> None:
#     215         # Caller is responsible for ensuring we have an Index object.
# --> 216         self._validate_set_axis(axis, new_labels)
#     217         self.axes[axis] = new_labels
#     218
#
# ~/projects/python/Bosch/venv/lib/python3.7/site-packages/pandas/core/internals/base.py in _validate_set_axis(self, axis, new_labels)
#      56         elif new_len != old_len:
#      57             raise ValueError(
# ---> 58                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      59                 f"values have {new_len} elements"
#      60             )
#
# ValueError: Length mismatch: Expected axis has 8 elements, new values have 7 elements

# %%
file2
# Out:
#          date             site_name dial_acc call_acc dial_non_acc  \
# 0  2021-09-01           tyreplus.ru        1        0            0
# 1  2021-09-01  [Yandex] tyreplus.ru        0        0            0
# 2  2021-09-01           michelin.ru       10        0            1
# 3  2021-09-01           VK [Мишлен]        0        0            0
# 4  2021-09-01         BFGoodrich.ru        0        0            0
# 5  2021-09-01   [Yandex] BFGoodrich        0        0            0
# 6  2021-09-01                Мишлен        1        0            0
# 7  2021-09-01  savefuel.michelin.ru        0        0            0
# 8  2021-09-01        b2b experience        0        0            0
#
#   call_non_acc dial_no_reply offline_msg
# 0            0             0           0
# 1            0             0           0
# 2            0             1           0
# 3            0             0           0
# 4            0             0           0
# 5            0             0           0
# 6            0             0           1
# 7            0             0           0
# 8            0             0           0
